# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# %cd /content/drive/My Drive/Sentence_pair_modeling/Models/ESIM/

# %%
! pip3 install hanziconv
! pip3 install jsonlines

# %% [markdown]
# # **LCQMC**

# %% [markdown]
# ## LCQMC train-validate-test

# %% [markdown]
# ### word embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

lcqmc_path = "/content/drive/My Drive/Sentence_pair_modeling/LCQMC/"
train_df = pd.read_csv(os.path.join(lcqmc_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(lcqmc_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(lcqmc_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])
vocab_file = os.path.join(lcqmc_path, "data/rand_word_vocab.txt")
target_dir = os.path.join(lcqmc_path, "output/ESIM_word_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_classes=2,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)

test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### word embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(lcqmc_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(lcqmc_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(lcqmc_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])
vocab_file = os.path.join(lcqmc_path, "data/pre_word_vocab.txt")
embeddings_file = os.path.join(lcqmc_path, "data/word_vec_300.iter5")
target_dir = os.path.join(lcqmc_path, "output/ESIM_word_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(lcqmc_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(lcqmc_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(lcqmc_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])

vocab_file = os.path.join(lcqmc_path, "data/rand_char_vocab.txt")

target_dir = os.path.join(lcqmc_path, "output/ESIM_char_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(lcqmc_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(lcqmc_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(lcqmc_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])
embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(lcqmc_path, "output/ESIM_char_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ## LCQMC infer by other pretrained models

# %%
from run_ESIM_model import model_load_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(lcqmc_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(lcqmc_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(lcqmc_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])
data = pd.concat([train_df,dev_df,test_df]).reset_index(drop=True)
embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(bq_path, "output/ESIM_char_pre/best.pth.tar") # load pretrained model
test_prediction_dir = os.path.join(bq_path, "output/Infer_LCQMC") # where to save the infer result
test_prediction_name = 'ESIM_test_prediction.csv' # the infer result name
 
model_load_test(test_df = data,
                vocab_file = vocab_file,
                embeddings_file = embeddings_file,
                pretrained_file = target_dir,
                test_prediction_dir = test_prediction_dir,
                test_prediction_name = test_prediction_name,
                mode = 'char',
                max_length=64,
                gpu_index=0, 
                batch_size=128)

test_result = pd.read_csv(os.path.join(test_prediction_dir, test_prediction_name))
Metric(data.label, test_result.prediction)

# %% [markdown]
# # **XiAn**

# %% [markdown]
# ## XiAn train-validate-test

# %% [markdown]
# ### word embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

xian_path = "/content/drive/My Drive/Sentence_pair_modeling/XiAn_STS/"
train_df = pd.read_csv(os.path.join(xian_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(xian_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(xian_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])

vocab_file = os.path.join(xian_path, "data/rand_word_vocab.txt")

target_dir = os.path.join(xian_path, "output/ESIM_word_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=20,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### word embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(xian_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(xian_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(xian_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])

vocab_file = os.path.join(lcqmc_path, "data/pre_word_vocab.txt")
embeddings_file = os.path.join(lcqmc_path, "data/word_vec_300.iter5")
target_dir = os.path.join(xian_path, "output/ESIM_word_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=20,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(xian_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(xian_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(xian_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])

vocab_file = os.path.join(xian_path, "data/rand_char_vocab.txt")

target_dir = os.path.join(xian_path, "output/ESIM_char_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(xian_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(xian_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(xian_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])

embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(xian_path, "output/ESIM_char_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ## XiAn infer by other pretrained models

# %%
from run_ESIM_model import model_load_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(xian_path, "data/train.tsv"),sep='\t',header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(xian_path, "data/dev.tsv"),sep='\t',header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(xian_path, "data/test.tsv"),sep='\t',header=None, names=['s1','s2','label'])
data = pd.concat([train_df,dev_df,test_df]).reset_index(drop=True)
embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(lcqmc_path, "output/ESIM_char_pre/best.pth.tar") # load pretrained model
test_prediction_dir = os.path.join(lcqmc_path, "output/Infer_XiAn") # where to save the infer result
test_prediction_name = 'ESIM_test_prediction.csv' # the infer result name

model_load_test(test_df = data,
                vocab_file = vocab_file,
                embeddings_file = embeddings_file,
                pretrained_file = target_dir,
                test_prediction_dir = test_prediction_dir,
                test_prediction_name = test_prediction_name,
                mode = 'char',
                max_length=64,
                gpu_index=0, 
                batch_size=128)

test_result = pd.read_csv(os.path.join(test_prediction_dir, test_prediction_name))
Metric(data.label, test_result.prediction)

# %% [markdown]
# # **BQ**

# %% [markdown]
# ## BQ train-validate-test

# %% [markdown]
# ### word embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric, json2df
import os

bq_path = "/content/drive/My Drive/Sentence_pair_modeling/BQ Corpus/"
train_df = json2df(os.path.join(bq_path, "data/train.json"))
dev_df = json2df(os.path.join(bq_path, "data/dev.json"))
test_df = json2df(os.path.join(bq_path, "data/test.json"))

vocab_file = os.path.join(bq_path, "data/rand_word_vocab.txt")

target_dir = os.path.join(bq_path, "output/ESIM_word_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### word embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric, json2df
import os

train_df = json2df(os.path.join(bq_path, "data/train.json"))
dev_df = json2df(os.path.join(bq_path, "data/dev.json"))
test_df = json2df(os.path.join(bq_path, "data/test.json"))
vocab_file = os.path.join(lcqmc_path, "data/pre_word_vocab.txt")
embeddings_file = os.path.join(lcqmc_path, "data/word_vec_300.iter5")

target_dir = os.path.join(bq_path, "output/ESIM_word_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric, json2df
import os

train_df = json2df(os.path.join(bq_path, "data/train.json"))
dev_df = json2df(os.path.join(bq_path, "data/dev.json"))
test_df = json2df(os.path.join(bq_path, "data/test.json"))

vocab_file = os.path.join(bq_path, "data/rand_char_vocab.txt")

target_dir = os.path.join(bq_path, "output/ESIM_char_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding-pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric, json2df
import os

train_df = json2df(os.path.join(bq_path, "data/train.json"))
dev_df = json2df(os.path.join(bq_path, "data/dev.json"))
test_df = json2df(os.path.join(bq_path, "data/test.json"))

embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(bq_path, "output/ESIM_char_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.2,
             num_labels=2,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ## BQ infer by other pretrained models

# %%
from run_ESIM_model import model_load_test
import pandas as pd
from utils import Metric, json2df
import os

train_df = json2df(os.path.join(bq_path, "data/train.json"))
dev_df = json2df(os.path.join(bq_path, "data/dev.json"))
test_df = json2df(os.path.join(bq_path, "data/test.json"))
data = pd.concat([train_df,dev_df,test_df]).reset_index(drop=True)
embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(lcqmc_path, "output/ESIM_char_pre/best.pth.tar") # load pretrained model
test_prediction_dir = os.path.join(lcqmc_path, "output/Infer_BQ") # where to save the infer result
test_prediction_name = 'ESIM_test_prediction.csv' # the infer result name

model_load_test(test_df = data,
                vocab_file = vocab_file,
                embeddings_file = embeddings_file,
                pretrained_file = target_dir,
                test_prediction_dir = test_prediction_dir,
                test_prediction_name = test_prediction_name,
                mode = 'char',
                max_length=64,
                gpu_index=0, 
                batch_size=128)

test_result = pd.read_csv(os.path.join(test_prediction_dir, test_prediction_name))
Metric(data.label, test_result.prediction)

# %% [markdown]
# # **OCNLI**

# %% [markdown]
# ### word embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

ocnli_path = "/content/drive/My Drive/Sentence_pair_modeling/OCNLI/"
train_df = pd.read_csv(os.path.join(ocnli_path, "data/train.csv"),header=None, names=['s1','s2','label','genre'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label','genre'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label','genre'])

vocab_file = os.path.join(ocnli_path, "data/word_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_word_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### word embedding pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

ocnli_path = "/content/drive/My Drive/Sentence_pair_modeling/OCNLI/"
train_df = pd.read_csv(os.path.join(ocnli_path, "data/train.csv"),header=None, names=['s1','s2','label','genre'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label','genre'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label','genre'])

vocab_file = os.path.join(ocnli_path, "data/word_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_word_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(ocnli_path, "data/train.csv"),header=None, names=['s1','s2','label','genre'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label','genre'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label','genre'])

vocab_file = os.path.join(ocnli_path, "data/char_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_char_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(ocnli_path, "data/train.csv"),header=None, names=['s1','s2','label','genre'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label','genre'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label','genre'])

embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_char_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# # **CMNLI**

# %% [markdown]
# ### word embedding pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

cmnli_path = "/content/drive/My Drive/Sentence_pair_modeling/CMNLI/"
train_df = pd.read_csv(os.path.join(ocnli_path, "data/train1.csv"),header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label'])
vocab_file = os.path.join(lcqmc_path, "data/pre_word_vocab.txt")
embeddings_file = os.path.join(lcqmc_path, "data/word_vec_300.iter5")

target_dir = os.path.join(ocnli_path, "output/ESIM_word_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'word',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding

# %%
import re
from hanziconv import HanziConv
import pandas as pd
def get_char_list(query):
    query = HanziConv.toSimplified(query.strip())
    regEx = re.compile('[\\W]+')#我们可以使用正则表达式来切分句子，切分的规则是除单词，数字外的任意字符串
    res = re.compile(r'([\u4e00-\u9fa5])')#[\u4e00-\u9fa5]中文范围
    sentences = regEx.split(query.lower())
    str_list = []
    for sentence in sentences:
        if res.split(sentence) == None:
            str_list.append(sentence)
        else:
            ret = res.split(sentence)
            str_list.extend(ret)
    return [w for w in str_list if len(w.strip()) > 0]

# %%
train_df = pd.read_csv("/content/drive/My Drive/CMNLI/data/train.csv",header=None, names=['s1','s2','similarity'])
dev_df = pd.read_csv("/content/drive/My Drive/CMNLI/data/dev.csv",header=None, names=['s1','s2','similarity'])
test_df = pd.read_csv("/content/drive/My Drive/CMNLI/data/test.csv",header=None, names=['s1','s2','similarity'])

# %%
def drop_length0(df_name):
  s1 = df_name.s1.apply(get_char_list)
  s2 = df_name.s2.apply(get_char_list)

  index_list1 = []
  for i in range(len(s1)):
    if (s1[i]==[]):
      index_list1.append(i)
  print(index_list1)

  index_list2 = []
  for i in range(len(s2)):
    if (s2[i]==[]):
      index_list2.append(i)
  print(index_list2)

  index_list = list(set(index_list1).union(set(index_list2)))
  print(index_list)

  train_df.drop(index=index_list).reset_index(drop=True).to_csv('/content/drive/My Drive/CMNLI/data/test1.csv', index=False, header=0)

# %%
drop_length0(test_df)

# %%
test_df.info()

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(ocnli_path, "data/train1.csv"),header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label'])

vocab_file = os.path.join(ocnli_path, "data/char_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_char_rand/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = None,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.001,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)

# %% [markdown]
# ### char embedding pretrained

# %%
from run_ESIM_model import model_train_validate_test
import pandas as pd
from utils import Metric
import os

train_df = pd.read_csv(os.path.join(ocnli_path, "data/train1.csv"),header=None, names=['s1','s2','label'])
dev_df = pd.read_csv(os.path.join(ocnli_path, "data/dev.csv"),header=None, names=['s1','s2','label'])
test_df = pd.read_csv(os.path.join(ocnli_path, "data/test.csv"),header=None, names=['s1','s2','label'])

embeddings_file = os.path.join(lcqmc_path, "data/token_vec_300.bin")
vocab_file = os.path.join(lcqmc_path, "data/pre_char_vocab.txt")

target_dir = os.path.join(ocnli_path, "output/ESIM_char_pre/")

model_train_validate_test(train_df = train_df,
             dev_df = dev_df,
             test_df = test_df,
             embeddings_file = embeddings_file,
             vocab_file = vocab_file,
             target_dir = target_dir,
             mode = 'char',
             max_length=64,
             hidden_size=200,
             dropout=0.4,
             num_labels=3,
             epochs=50,
             batch_size=256,
             lr=0.0005,
             patience=3,
             max_grad_norm=10.0,
             gpu_index=0,
             if_save_model=False,
             checkpoint=None)
  
test_result = pd.read_csv(os.path.join(target_dir, 'test_prediction.csv'))
Metric(test_df.label, test_result.prediction)
